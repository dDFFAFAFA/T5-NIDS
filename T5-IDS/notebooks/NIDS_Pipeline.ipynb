# %% [markdown]
# # NIDS Pipeline
#
# Scaffold notebook for preprocessing, pretraining, and finetuning.

# %%
# TODO: import your modules and run the pipeline here.
# from src.data.preprocessing import bytes_to_hex
# from src.training.trainer import Trainer
